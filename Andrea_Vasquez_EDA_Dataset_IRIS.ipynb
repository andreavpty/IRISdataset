# %% [markdown]
# # Iris Dataset

# %% [markdown]
# # Nueva sección

# %% [markdown]
# EDA CSV IRIS: Partiendo del dataset "Iris" ([DESCARGAR AQUÍ](https://thevalley.es/lms/downloads/python/Iris.csv), consulta la [doc oficial](https://archive.ics.uci.edu/ml/datasets/iris) ) realizar las siguiente tareas con Pandas, numpy y matplotlib:
#
# 1. Cargar los datos desde el csv
# 2. Primer vistazo a las primeras 8 filas del dataset y a las 12 últimas
# 3. Comprobar el tamaño del dataset
# 4. Guardar el nombre de las columnas en una lista
# 5. Comprobar los tipos de cada variable
# 6. ¿Hay valores nulos en nuestro dataset? ¿Cuántos?
# 7. ¿Cuántas especies de plantas distintas tenemos?
# 8. ¿Cuántas plantas hay de cada especie?
# 9. Representar lo anterior en un gráfico de barras
# 10. Calcular máximo, mínimo, media, mediana y desviación típica de la longitud de los pétalos
# 11. Guardar en un nuevo dataframe las flores de la especie setosa con longitud de sépalo mayor o igual a 5
# 12. Representar la relación en un scatter plot entre la longitud y ancho de sépalo
# 11. Pintar la relación anterior pero donde los puntos de longitud mayor a 3 estan en color rojo, mientras que el resto en azul
# 14. Representar el boxplot del ancho de los pétalos

# %% [markdown]
# **BoxPlot and its meaning**

# %%
#Let's define the essential libraries required.
import numpy as np                                   #for array
import pandas as pd                                  #for dataframe
import matplotlib.pyplot as plt                      #for visualization
# %matplotlib inline
import seaborn as sns                                #for visualization
import warnings ; warnings.filterwarnings('ignore')  #for warnings->codes run smoother

# %%
pd.read_csv("Iris.csv")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_df = pd.read_csv("Iris.csv")

# %%
iris_df.head(8)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa

# %%
iris_df.tail(12)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# ...

# %%
iris_df.shape
# Out:
# (150, 6)

# %%
iris_df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_df.columns.to_list()
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
columnas=iris_df.columns.to_list()

# %%
columnas
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
columnas[2:4]
# Out:
# ['SepalWidthCm', 'PetalLengthCm']

# %%
iris_df[columnas[2:4]].head()
# Out:
#    SepalWidthCm  PetalLengthCm
# 0           3.5            1.4
# 1           3.0            1.4
# 2           3.2            1.3
# 3           3.1            1.5
# 4           3.6            1.4

# %%
iris_df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris_df.isna()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
np.sum(iris_df.isna())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_df.fillna(0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_df['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
iris_df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
especies = iris_df['Species'].unique().tolist()

# %%
conteo = iris_df['Species'].value_counts().tolist()

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.bar(especies,conteo)

plt.show()

# %%
iris_df['PetalLengthCm']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
np.mean(iris_df['PetalLengthCm'])
# Out:
# 3.758666666666666

# %%
np.median(iris_df['PetalLengthCm'])
# Out:
# 4.35

# %%
np.max(iris_df['PetalLengthCm'])
# Out:
# 6.9

# %%
np.min(iris_df['PetalLengthCm'])
# Out:
# 1.0

# %%
np.std(iris_df['PetalLengthCm'])
# Out:
# 1.7585291834055212

# %%
iris_filtered_df = iris_df[(iris_df.Species == "Iris-setosa")&(iris_df.SepalLengthCm >=5)]

# %%
iris_filtered_df.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa

# %%
iris_filtered_df.shape
# Out:
# (30, 6)

# %%
plt.figure(figsize=(8,5),dpi=100)

plt.scatter(iris_df.SepalLengthCm, iris_df.SepalWidthCm)

plt.show()

# %%
plt.figure(figsize=(8,5),dpi=100)

plt.scatter(iris_df[iris_df.SepalWidthCm >=3].SepalLengthCm, iris_df[iris_df.SepalWidthCm >=3].SepalWidthCm,color="red")
plt.scatter(iris_df[iris_df.SepalWidthCm <3].SepalLengthCm, iris_df[iris_df.SepalWidthCm <3].SepalWidthCm,color="blue")

plt.show()

# %%
iris_df.PetalWidthCm
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PetalWidthCm, Length: 150, dtype: float64

# %%
plt.figure(figsize=(8,5),dpi=100)

plt.boxplot(iris_df.PetalWidthCm)

plt.show()
